# %% [markdown]
# ## scANVI analysis for healthy PBMC pilot study (Cai 2020 and Cai 2022)
#
# **Objective**: Run scANVI analysis for label transfer for healthy PBMCs [Cai 2020 and Cai 2022]
#
#
# - **Developed by**: Mairi McClean
#
# - **Institute of Computational Biology - Computational Health Centre - Helmholtz Munich**
#
# - v230317
#
# - Following this tutorial: https://docs.scvi-tools.org/en/stable/tutorials/notebooks/scarches_scvi_tools.html
# > "This particular workflow is useful in the case where a model is trained on some data (called reference here) and new samples are received (called query)."

# %%
# Sanity check
import os 
os.write(1, b"text\n")
# Out:
# text
# 5

# %% [markdown]
# ### Import modules

# %%
import sys
import warnings

import anndata
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import scrublet as scr
import scvi
# Out:
# Global seed set to 0
# /Users/mairi.mcclean/mambaforge/envs/label_transfer_scvi/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /Users/mairi.mcclean/mambaforge/envs/label_transfer_scvi/lib/python3.9/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)

# %%
warnings.simplefilter(action="ignore", category=FutureWarning)


sc.set_figure_params(figsize=(4, 4))
scvi.settings.seed = 94705

# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
# %config InlineBackend.figure_format='retina'
# Out:
# Global seed set to 94705

# %% [markdown]
# ### Read in data

# %%
yoshida = sc.read_h5ad('/Volumes/Lacie/data_lake/Mairi_example/INBOX/sc_downloads/yoshida_2021/meyer_nikolic_covid_pbmc.cellxgene.20210813.h5ad')

yoshida
# Out:
# AnnData object with n_obs × n_vars = 422220 × 33751
#     obs: 'patient_id', 'Ethnicity', 'BMI', 'annotation_broad', 'annotation_detailed', 'annotation_detailed_fullNames', 'Age_group', 'COVID_severity', 'COVID_status', 'Group', 'Sex', 'Smoker', 'sample_id', 'sequencing_library', 'Protein_modality_weight'
#     var: 'name'
#     obsm: 'X_ umap (wnn derived)', 'X_umap (after harmony ADT)', 'X_umap (after harmony RNA)', 'X_umap (before harmony ADT)', 'X_umap (before harmony RNA)'

# %%
yoshida.obs
# Out:
#                                                    patient_id Ethnicity
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...        AN5       EUR  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        AN5       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        AN3       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...        AN5       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...        AN5       EUR
# ...                                                       ...       ...
# S28_TTTGTCAGTTCTGTTT-1                                    PC9       EUR
# S28_TTTGTCATCAACCAAC-1                                    PC9       EUR
# S28_TTTGTCATCATTATCC-1                                    PC9       EUR
# S28_TTTGTCATCCTATGTT-1                                    PC9       EUR
# S28_TTTGTCATCTCAAGTG-1                                    PC2       EUR
#
#                                                         BMI annotation_broad
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  Unknown         Monocyte  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  Unknown           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  Unknown           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  Unknown           T CD8+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  Unknown           T CD4+
# ...                                                     ...              ...
# S28_TTTGTCAGTTCTGTTT-1                                27.17               NK
# S28_TTTGTCATCAACCAAC-1                                27.17         Monocyte
# S28_TTTGTCATCATTATCC-1                                27.17         Monocyte
# S28_TTTGTCATCCTATGTT-1                                27.17               DC
# S28_TTTGTCATCTCAAGTG-1                                 36.9           T CD8+
#
#                                                    annotation_detailed
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       Monocyte CD14  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive
# ...                                                                ...
# S28_TTTGTCAGTTCTGTTT-1                                              NK
# S28_TTTGTCATCAACCAAC-1                                   Monocyte CD14
# S28_TTTGTCATCATTATCC-1                                   Monocyte CD14
# S28_TTTGTCATCCTATGTT-1                                             pDC
# S28_TTTGTCATCTCAAGTG-1                                       T CD8 CTL
#
#                                                    annotation_detailed_fullNames
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...            Classical monocyte  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...                  T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...                  T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...                   T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...                   T CD4 naive
# ...                                                                          ...
# S28_TTTGTCAGTTCTGTTT-1                                                        NK
# S28_TTTGTCATCAACCAAC-1                                        Classical monocyte
# S28_TTTGTCATCATTATCC-1                                        Classical monocyte
# S28_TTTGTCATCCTATGTT-1                                                       pDC
# S28_TTTGTCATCTCAAGTG-1                                                 T CD8 CTL
#
#                                                    Age_group COVID_severity
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...     Adult        Healthy  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...     Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...     Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...     Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...     Adult        Healthy
# ...                                                      ...            ...
# S28_TTTGTCAGTTCTGTTT-1                                 Adult         Severe
# S28_TTTGTCATCAACCAAC-1                                 Adult         Severe
# S28_TTTGTCATCATTATCC-1                                 Adult         Severe
# S28_TTTGTCATCCTATGTT-1                                 Adult         Severe
# S28_TTTGTCATCTCAAGTG-1                                 Adult         Severe
#
#                                                      COVID_status  Group
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...        Healthy  Adult  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        Healthy  Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        Healthy  Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...        Healthy  Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...        Healthy  Adult
# ...                                                           ...    ...
# S28_TTTGTCAGTTCTGTTT-1                              Post-COVID-19  Adult
# S28_TTTGTCATCAACCAAC-1                              Post-COVID-19  Adult
# S28_TTTGTCATCATTATCC-1                              Post-COVID-19  Adult
# S28_TTTGTCATCCTATGTT-1                              Post-COVID-19  Adult
# S28_TTTGTCATCTCAAGTG-1                              Post-COVID-19  Adult
#
#                                                        Sex      Smoker
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  Female  Non-smoker  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  Female  Non-smoker
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...    Male  Non-smoker
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  Female  Non-smoker
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  Female  Non-smoker
# ...                                                    ...         ...
# S28_TTTGTCAGTTCTGTTT-1                                Male  Non-smoker
# S28_TTTGTCATCAACCAAC-1                                Male  Non-smoker
# S28_TTTGTCATCATTATCC-1                                Male  Non-smoker
# S28_TTTGTCATCCTATGTT-1                                Male  Non-smoker
# S28_TTTGTCATCTCAAGTG-1                                Male  Non-smoker
#
#                                                    sample_id
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       AN5  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...       AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...       AN3
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...       AN5
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...       AN5
# ...                                                      ...
# S28_TTTGTCAGTTCTGTTT-1                                   PC9
# S28_TTTGTCATCAACCAAC-1                                   PC9
# S28_TTTGTCATCATTATCC-1                                   PC9
# S28_TTTGTCATCCTATGTT-1                                   PC9
# S28_TTTGTCATCTCAAGTG-1                                   PC2
#
#                                                                    sequencing_library
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  CV001_KM10202384-CV001_KM10202394  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  CV001_KM10202384-CV001_KM10202394
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  CV001_KM10202384-CV001_KM10202394
# ...                                                                               ...
# S28_TTTGTCAGTTCTGTTT-1                                CV001_KM9294396-CV001_KM9294404
# S28_TTTGTCATCAACCAAC-1                                CV001_KM9294396-CV001_KM9294404
# S28_TTTGTCATCATTATCC-1                                CV001_KM9294396-CV001_KM9294404
# S28_TTTGTCATCCTATGTT-1                                CV001_KM9294396-CV001_KM9294404
# S28_TTTGTCATCTCAAGTG-1                                CV001_KM9294396-CV001_KM9294404
#
#                                                     Protein_modality_weight
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...                 0.359517
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...                 0.577522
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...                 0.369143
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...                 0.785563
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...                 0.564174
# ...                                                                     ...
# S28_TTTGTCAGTTCTGTTT-1                                             0.429398
# S28_TTTGTCATCAACCAAC-1                                             0.677910
# S28_TTTGTCATCATTATCC-1                                             0.422796
# S28_TTTGTCATCCTATGTT-1                                             0.471905
# S28_TTTGTCATCTCAAGTG-1                                             0.313640
#
# [422220 rows x 15 columns]

# %%
yoshida.obs['COVID_status'].value_counts()
# Out:
# COVID_status
# Healthy          173684
# COVID-19         151312
# Post-COVID-19     97224
# Name: count, dtype: int64

# %%
reference = yoshida[yoshida.obs['COVID_status'] == 'Healthy']

reference
# Out:
# View of AnnData object with n_obs × n_vars = 173684 × 33751
#     obs: 'patient_id', 'Ethnicity', 'BMI', 'annotation_broad', 'annotation_detailed', 'annotation_detailed_fullNames', 'Age_group', 'COVID_severity', 'COVID_status', 'Group', 'Sex', 'Smoker', 'sample_id', 'sequencing_library', 'Protein_modality_weight'
#     var: 'name'
#     obsm: 'X_ umap (wnn derived)', 'X_umap (after harmony ADT)', 'X_umap (after harmony RNA)', 'X_umap (before harmony ADT)', 'X_umap (before harmony RNA)'

# %%
reference.obs['COVID_status'].value_counts()
# Out:
# COVID_status
# Healthy    173684
# Name: count, dtype: int64

# %%
# Note: Query data is that of only Cai, not the Cai+Yoshida data, but clustered following scvi. This is not the correct data object?

# adata_query = sc.read_h5ad('/Volumes/Lacie/data_lake/Mairi_example/processed_files/scvi/post_sccaf/CaiY_healthy_scRNA_PBMC_mm230316_scVI-clustered.raw.h5ad')

cai = sc.read_h5ad('/Volumes/LaCie/data_lake/Mairi_example/processed_files/abridged_qc/human/Cai2020_scRNA_PBMC_mm230315_qcd.h5ad')
cai
# Out:
# AnnData object with n_obs × n_vars = 73146 × 61533
#     obs: 'study', 'individual', 'sample', 'tissue', 'donor', 'age', 'gender', 'status', 'data_type', 'centre', 'version', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'predicted_doublets'
#     var: 'gene_id', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'donor_colors'
#     layers: 'counts', 'sqrt_norm'

# %%
cai.obs
# Out:
#                             study    individual     sample tissue
# barcode
# AAACCTGAGAACAATC-acTB3  CaiY_2021  SAMN14048025  PBMC_TB_3   PBMC  \
# AAACCTGAGAAGGTGA-acTB3  CaiY_2021  SAMN14048025  PBMC_TB_3   PBMC
# AAACCTGAGATCTGCT-acTB3  CaiY_2021  SAMN14048025  PBMC_TB_3   PBMC
# AAACCTGAGCACAGGT-acTB3  CaiY_2021  SAMN14048025  PBMC_TB_3   PBMC
# AAACCTGAGCGTGAAC-acTB3  CaiY_2021  SAMN14048025  PBMC_TB_3   PBMC
# ...                           ...           ...        ...    ...
# TTTGTCAGTCGCGGTT-H1     CaiY_2021  SAMN14048019  PBMC_HC_1   PBMC
# TTTGTCAGTCGCTTCT-H1     CaiY_2021  SAMN14048019  PBMC_HC_1   PBMC
# TTTGTCAGTTCGAATC-H1     CaiY_2021  SAMN14048019  PBMC_HC_1   PBMC
# TTTGTCAGTTTGGGCC-H1     CaiY_2021  SAMN14048019  PBMC_HC_1   PBMC
# TTTGTCATCCCATTAT-H1     CaiY_2021  SAMN14048019  PBMC_HC_1   PBMC
#
#                                donor age gender     status data_type
# barcode
# AAACCTGAGAACAATC-acTB3  SAMN14048025  34   male  active_TB  scRNAseq  \
# AAACCTGAGAAGGTGA-acTB3  SAMN14048025  34   male  active_TB  scRNAseq
# AAACCTGAGATCTGCT-acTB3  SAMN14048025  34   male  active_TB  scRNAseq
# AAACCTGAGCACAGGT-acTB3  SAMN14048025  34   male  active_TB  scRNAseq
# AAACCTGAGCGTGAAC-acTB3  SAMN14048025  34   male  active_TB  scRNAseq
# ...                              ...  ..    ...        ...       ...
# TTTGTCAGTCGCGGTT-H1     SAMN14048019  26   male    Healthy  scRNAseq
# TTTGTCAGTCGCTTCT-H1     SAMN14048019  26   male    Healthy  scRNAseq
# TTTGTCAGTTCGAATC-H1     SAMN14048019  26   male    Healthy  scRNAseq
# TTTGTCAGTTTGGGCC-H1     SAMN14048019  26   male    Healthy  scRNAseq
# TTTGTCATCCCATTAT-H1     SAMN14048019  26   male    Healthy  scRNAseq
#
#                                      centre  ... pct_counts_mt
# barcode                                      ...
# AAACCTGAGAACAATC-acTB3  Shenzhen University  ...      6.017039  \
# AAACCTGAGAAGGTGA-acTB3  Shenzhen University  ...      1.668552
# AAACCTGAGATCTGCT-acTB3  Shenzhen University  ...      9.967497
# AAACCTGAGCACAGGT-acTB3  Shenzhen University  ...      4.557977
# AAACCTGAGCGTGAAC-acTB3  Shenzhen University  ...      2.457002
# ...                                     ...  ...           ...
# TTTGTCAGTCGCGGTT-H1     Shenzhen University  ...      3.250689
# TTTGTCAGTCGCTTCT-H1     Shenzhen University  ...      4.287570
# TTTGTCAGTTCGAATC-H1     Shenzhen University  ...      6.650446
# TTTGTCAGTTTGGGCC-H1     Shenzhen University  ...      3.483043
# TTTGTCATCCCATTAT-H1     Shenzhen University  ...      2.702703
#
#                        total_counts_ribo  pct_counts_ribo  percent_mt2
# barcode
# AAACCTGAGAACAATC-acTB3            1676.0        29.747959     0.060170  \
# AAACCTGAGAAGGTGA-acTB3            1901.0        53.761311     0.016686
# AAACCTGAGATCTGCT-acTB3             367.0        19.880823     0.099675
# AAACCTGAGCACAGGT-acTB3             772.0        19.333836     0.045580
# AAACCTGAGCGTGAAC-acTB3            1003.0        49.287468     0.024570
# ...                                  ...              ...          ...
# TTTGTCAGTCGCGGTT-H1               1904.0        52.451790     0.032507
# TTTGTCAGTCGCTTCT-H1                868.0        37.592033     0.042876
# TTTGTCAGTTCGAATC-H1                712.0        28.872669     0.066504
# TTTGTCAGTTTGGGCC-H1               1555.0        47.509930     0.034830
# TTTGTCATCCCATTAT-H1                162.0        24.324326     0.027027
#
#                         n_counts  percent_chrY  XIST-counts   S_score
# barcode
# AAACCTGAGAACAATC-acTB3    5634.0      0.053248          0.0 -0.352188  \
# AAACCTGAGAAGGTGA-acTB3    3536.0      0.113122          0.0 -0.064944
# AAACCTGAGATCTGCT-acTB3    1846.0      0.054171          0.0 -0.231399
# AAACCTGAGCACAGGT-acTB3    3993.0      0.075131          0.0 -0.227884
# AAACCTGAGCGTGAAC-acTB3    2035.0      0.147420          0.0  0.020959
# ...                          ...           ...          ...       ...
# TTTGTCAGTCGCGGTT-H1       3630.0      0.110193          0.0 -0.165353
# TTTGTCAGTCGCTTCT-H1       2309.0      0.043309          0.0 -0.177318
# TTTGTCAGTTCGAATC-H1       2466.0      0.040551          0.0 -0.235875
# TTTGTCAGTTTGGGCC-H1       3273.0      0.091659          0.0 -0.050351
# TTTGTCATCCCATTAT-H1        666.0      0.300300          0.0  0.080008
#
#                         G2M_score  predicted_doublets
# barcode
# AAACCTGAGAACAATC-acTB3  -0.193287                 0.0
# AAACCTGAGAAGGTGA-acTB3  -0.071169                 0.0
# AAACCTGAGATCTGCT-acTB3  -0.080643                 0.0
# AAACCTGAGCACAGGT-acTB3  -0.258770                 0.0
# AAACCTGAGCGTGAAC-acTB3   0.025030                 0.0
# ...                           ...                 ...
# TTTGTCAGTCGCGGTT-H1     -0.250572                 0.0
# TTTGTCAGTCGCTTCT-H1     -0.173327                 0.0
# TTTGTCAGTTCGAATC-H1     -0.013744                 0.0
# TTTGTCAGTTTGGGCC-H1      0.022269                 0.0
# TTTGTCATCCCATTAT-H1      0.039641                 0.0
#
# [73146 rows x 26 columns]

# %%
cai.obs['status'].value_counts()
# Out:
# status
# active_TB    33104
# Healthy      22049
# latent_TB    17993
# Name: count, dtype: int64

# %%
query = cai[cai.obs['status'] == 'Healthy']
query
# Out:
# View of AnnData object with n_obs × n_vars = 22049 × 61533
#     obs: 'study', 'individual', 'sample', 'tissue', 'donor', 'age', 'gender', 'status', 'data_type', 'centre', 'version', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'predicted_doublets'
#     var: 'gene_id', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'donor_colors'
#     layers: 'counts', 'sqrt_norm'

# %%
query.obs['status'].value_counts()
# Out:
# status
# Healthy    22049
# Name: count, dtype: int64

# %%
def X_is_raw(adata):
    return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis=0))

# %%
X_is_raw(query)
# Out:
# False

# %%
X_is_raw(query)
# Out:
# False

# %%
reference.obs['seed_labels'] = reference.obs['annotation_broad'].copy()
# Out:
# /var/folders/g6/vfgrx_y95ml0h2lsgfx4jg6jwvdsz3/T/ipykernel_2106/3136194272.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   reference.obs['seed_labels'] = reference.obs['annotation_broad'].copy()

# %%
query.obs['seed_labels'] = 'Unknown'
# Out:
# /var/folders/g6/vfgrx_y95ml0h2lsgfx4jg6jwvdsz3/T/ipykernel_2106/141644025.py:1: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   query.obs['seed_labels'] = 'Unknown'

# %%
reference.var
# Out:
#                     name
# MIR1302-2HG  MIR1302-2HG
# FAM138A          FAM138A
# OR4F5              OR4F5
# AL627309.1    AL627309.1
# AL627309.3    AL627309.3
# ...                  ...
# AB-TRAC          AB-TRAC
# AB-TRG            AB-TRG
# AB-TIGIT        AB-TIGIT
# AB-CRLF2        AB-CRLF2
# AB-XCR1          AB-XCR1
#
# [33751 rows x 1 columns]

# %%
reference.var.rename(columns = {'name': 'gene_name'}, inplace = True)

# %%
# Why is this necessary?

reference.obs_names_make_unique()
query.obs_names_make_unique()
reference.var_names_make_unique()
query.var_names_make_unique()

# %%
# Check if genes in reference and query are the same
genes_reference = list(reference.var.index)
genes_query = list(query.var.index)
genes_in_reference = [gene for gene in genes_query if gene in genes_reference]

# %%
# Check if genes in reference and query are the same
cells_reference = list(reference.obs.index)
cells_query = list(query.obs.index)
cells_in_reference = [cell for cell in cells_query if cell in cells_reference]

# %% [markdown]
# - Concatenate both datasets

# %%
adata = reference.concatenate(query, batch_categories=['reference', 'query'], batch_key='dataset')
# Out:
# /Users/mairi.mcclean/mambaforge/envs/label_transfer_scvi/lib/python3.9/site-packages/anndata/_core/merge.py:1111: UserWarning: Only some AnnData objects have `.raw` attribute, not concatenating `.raw` attributes.
#   warn(

# %%
adata.X
# Out:
# <195733x22792 sparse matrix of type '<class 'numpy.float32'>'
# 	with 242201046 stored elements in Compressed Sparse Row format>

# %%
adata.obs
# Out:
#                                                    patient_id Ethnicity
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...        AN5       EUR  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        AN5       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        AN3       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...        AN5       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...        AN5       EUR
# ...                                                       ...       ...
# TTTGTCAGTCGCGGTT-H1-query                                 NaN       NaN
# TTTGTCAGTCGCTTCT-H1-query                                 NaN       NaN
# TTTGTCAGTTCGAATC-H1-query                                 NaN       NaN
# TTTGTCAGTTTGGGCC-H1-query                                 NaN       NaN
# TTTGTCATCCCATTAT-H1-query                                 NaN       NaN
#
#                                                         BMI annotation_broad
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  Unknown         Monocyte  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  Unknown           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  Unknown           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  Unknown           T CD8+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  Unknown           T CD4+
# ...                                                     ...              ...
# TTTGTCAGTCGCGGTT-H1-query                               NaN              NaN
# TTTGTCAGTCGCTTCT-H1-query                               NaN              NaN
# TTTGTCAGTTCGAATC-H1-query                               NaN              NaN
# TTTGTCAGTTTGGGCC-H1-query                               NaN              NaN
# TTTGTCATCCCATTAT-H1-query                               NaN              NaN
#
#                                                    annotation_detailed
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       Monocyte CD14  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive
# ...                                                                ...
# TTTGTCAGTCGCGGTT-H1-query                                          NaN
# TTTGTCAGTCGCTTCT-H1-query                                          NaN
# TTTGTCAGTTCGAATC-H1-query                                          NaN
# TTTGTCAGTTTGGGCC-H1-query                                          NaN
# TTTGTCATCCCATTAT-H1-query                                          NaN
#
#                                                    annotation_detailed_fullNames
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...            Classical monocyte  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...                  T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...                  T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...                   T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...                   T CD4 naive
# ...                                                                          ...
# TTTGTCAGTCGCGGTT-H1-query                                                    NaN
# TTTGTCAGTCGCTTCT-H1-query                                                    NaN
# TTTGTCAGTTCGAATC-H1-query                                                    NaN
# TTTGTCAGTTTGGGCC-H1-query                                                    NaN
# TTTGTCATCCCATTAT-H1-query                                                    NaN
#
#                                                    Age_group COVID_severity
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...     Adult        Healthy  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...     Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...     Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...     Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...     Adult        Healthy
# ...                                                      ...            ...
# TTTGTCAGTCGCGGTT-H1-query                                NaN            NaN
# TTTGTCAGTCGCTTCT-H1-query                                NaN            NaN
# TTTGTCAGTTCGAATC-H1-query                                NaN            NaN
# TTTGTCAGTTTGGGCC-H1-query                                NaN            NaN
# TTTGTCATCCCATTAT-H1-query                                NaN            NaN
#
#                                                    COVID_status  Group  ...
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...      Healthy  Adult  ...  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...      Healthy  Adult  ...
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...      Healthy  Adult  ...
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...      Healthy  Adult  ...
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...      Healthy  Adult  ...
# ...                                                         ...    ...  ...
# TTTGTCAGTCGCGGTT-H1-query                                   NaN    NaN  ...
# TTTGTCAGTCGCTTCT-H1-query                                   NaN    NaN  ...
# TTTGTCAGTTCGAATC-H1-query                                   NaN    NaN  ...
# TTTGTCAGTTTGGGCC-H1-query                                   NaN    NaN  ...
# TTTGTCATCCCATTAT-H1-query                                   NaN    NaN  ...
#
#                                                    total_counts_ribo
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...               NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...               NaN
# ...                                                              ...
# TTTGTCAGTCGCGGTT-H1-query                                     1904.0
# TTTGTCAGTCGCTTCT-H1-query                                      868.0
# TTTGTCAGTTCGAATC-H1-query                                      712.0
# TTTGTCAGTTTGGGCC-H1-query                                     1555.0
# TTTGTCATCCCATTAT-H1-query                                      162.0
#
#                                                    pct_counts_ribo
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...             NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...             NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...             NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...             NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...             NaN
# ...                                                            ...
# TTTGTCAGTCGCGGTT-H1-query                                52.451790
# TTTGTCAGTCGCTTCT-H1-query                                37.592033
# TTTGTCAGTTCGAATC-H1-query                                28.872669
# TTTGTCAGTTTGGGCC-H1-query                                47.509930
# TTTGTCATCCCATTAT-H1-query                                24.324326
#
#                                                    percent_mt2 n_counts
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...         NaN      NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...         NaN      NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...         NaN      NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         NaN      NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         NaN      NaN
# ...                                                        ...      ...
# TTTGTCAGTCGCGGTT-H1-query                             0.032507   3630.0
# TTTGTCAGTCGCTTCT-H1-query                             0.042876   2309.0
# TTTGTCAGTTCGAATC-H1-query                             0.066504   2466.0
# TTTGTCAGTTTGGGCC-H1-query                             0.034830   3273.0
# TTTGTCATCCCATTAT-H1-query                             0.027027    666.0
#
#                                                     percent_chrY XIST-counts
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...           NaN         NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...           NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...           NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...           NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...           NaN         NaN
# ...                                                          ...         ...
# TTTGTCAGTCGCGGTT-H1-query                               0.110193         0.0
# TTTGTCAGTCGCTTCT-H1-query                               0.043309         0.0
# TTTGTCAGTTCGAATC-H1-query                               0.040551         0.0
# TTTGTCAGTTTGGGCC-H1-query                               0.091659         0.0
# TTTGTCATCCCATTAT-H1-query                               0.300300         0.0
#
#                                                      S_score G2M_score
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       NaN       NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...       NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...       NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...       NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...       NaN       NaN
# ...                                                      ...       ...
# TTTGTCAGTCGCGGTT-H1-query                          -0.165353 -0.250572
# TTTGTCAGTCGCTTCT-H1-query                          -0.177318 -0.173327
# TTTGTCAGTTCGAATC-H1-query                          -0.235875 -0.013744
# TTTGTCAGTTTGGGCC-H1-query                          -0.050351  0.022269
# TTTGTCATCCCATTAT-H1-query                           0.080008  0.039641
#
#                                                    predicted_doublets
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...                NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...                NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...                NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...                NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...                NaN
# ...                                                               ...
# TTTGTCAGTCGCGGTT-H1-query                                         0.0
# TTTGTCAGTCGCTTCT-H1-query                                         0.0
# TTTGTCAGTTCGAATC-H1-query                                         0.0
# TTTGTCAGTTTGGGCC-H1-query                                         0.0
# TTTGTCATCCCATTAT-H1-query                                         0.0
#
#                                                       dataset
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  reference
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  reference
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  reference
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  reference
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  reference
# ...                                                       ...
# TTTGTCAGTCGCGGTT-H1-query                               query
# TTTGTCAGTCGCTTCT-H1-query                               query
# TTTGTCAGTTCGAATC-H1-query                               query
# TTTGTCAGTTTGGGCC-H1-query                               query
# TTTGTCATCCCATTAT-H1-query                               query
#
# [195733 rows x 43 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 195733 × 22792
#     obs: 'patient_id', 'Ethnicity', 'BMI', 'annotation_broad', 'annotation_detailed', 'annotation_detailed_fullNames', 'Age_group', 'COVID_severity', 'COVID_status', 'Group', 'Sex', 'Smoker', 'sample_id', 'sequencing_library', 'Protein_modality_weight', 'seed_labels', 'study', 'individual', 'sample', 'tissue', 'donor', 'age', 'gender', 'status', 'data_type', 'centre', 'version', 'batch', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'predicted_doublets', 'dataset'
#     var: 'gene_id-query', 'mt-query', 'ribo-query', 'n_cells_by_counts-query', 'mean_counts-query', 'pct_dropout_by_counts-query', 'total_counts-query', 'gene_name-reference'

# %%
# Replace NaN values in patient ID column

adata.obs['patient_id'] = adata.obs['patient_id'].cat.add_categories("unknown").fillna("unknown")

# %% [markdown]
# - Make reference and query objects from original adata object

# %%
query = np.array([s in ["query"] for s in adata.obs.dataset])

adata_ref = adata[~query].copy()
adata_query = adata[query].copy()

# %%
adata_ref.obs
# Out:
#                                                    patient_id Ethnicity
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...        AN5       EUR  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        AN5       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        AN3       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...        AN5       EUR
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...        AN5       EUR
# ...                                                       ...       ...
# S22_TTTGTCAGTCGCATCG-1-reference                         NP32       EUR
# S22_TTTGTCAGTGTAAGTA-1-reference                         NP32       EUR
# S22_TTTGTCATCATGTCCC-1-reference                         NP31       AFR
# S22_TTTGTCATCGAGGTAG-1-reference                         NP31       AFR
# S22_TTTGTCATCTGCTGCT-1-reference                         NP32       EUR
#
#                                                         BMI annotation_broad
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  Unknown         Monocyte  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  Unknown           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  Unknown           T CD4+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  Unknown           T CD8+
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  Unknown           T CD4+
# ...                                                     ...              ...
# S22_TTTGTCAGTCGCATCG-1-reference                       24.7           T CD8+
# S22_TTTGTCAGTGTAAGTA-1-reference                       24.7               NK
# S22_TTTGTCATCATGTCCC-1-reference                       18.2         Monocyte
# S22_TTTGTCATCGAGGTAG-1-reference                       18.2           T CD8+
# S22_TTTGTCATCTGCTGCT-1-reference                       24.7               NK
#
#                                                    annotation_detailed
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       Monocyte CD14  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...        T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         T CD4 naive
# ...                                                                ...
# S22_TTTGTCAGTCGCATCG-1-reference                           T CD8 naive
# S22_TTTGTCAGTGTAAGTA-1-reference                           NK IFN stim
# S22_TTTGTCATCATGTCCC-1-reference                         Monocyte CD14
# S22_TTTGTCATCGAGGTAG-1-reference                           T CD8 naive
# S22_TTTGTCATCTGCTGCT-1-reference                                    NK
#
#                                                    annotation_detailed_fullNames
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...            Classical monocyte  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...                  T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...                  T CD4 helper
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...                   T CD8 naive
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...                   T CD4 naive
# ...                                                                          ...
# S22_TTTGTCAGTCGCATCG-1-reference                                     T CD8 naive
# S22_TTTGTCAGTGTAAGTA-1-reference                                     NK IFN stim
# S22_TTTGTCATCATGTCCC-1-reference                              Classical monocyte
# S22_TTTGTCATCGAGGTAG-1-reference                                     T CD8 naive
# S22_TTTGTCATCTGCTGCT-1-reference                                              NK
#
#                                                      Age_group COVID_severity
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...       Adult        Healthy  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...       Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...       Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...       Adult        Healthy
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...       Adult        Healthy
# ...                                                        ...            ...
# S22_TTTGTCAGTCGCATCG-1-reference                    Adolescent        Healthy
# S22_TTTGTCAGTGTAAGTA-1-reference                    Adolescent        Healthy
# S22_TTTGTCATCATGTCCC-1-reference                         Child        Healthy
# S22_TTTGTCATCGAGGTAG-1-reference                         Child        Healthy
# S22_TTTGTCATCTGCTGCT-1-reference                    Adolescent        Healthy
#
#                                                    COVID_status       Group
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...      Healthy       Adult  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...      Healthy       Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...      Healthy       Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...      Healthy       Adult
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...      Healthy       Adult
# ...                                                         ...         ...
# S22_TTTGTCAGTCGCATCG-1-reference                        Healthy  Paediatric
# S22_TTTGTCAGTGTAAGTA-1-reference                        Healthy  Paediatric
# S22_TTTGTCATCATGTCCC-1-reference                        Healthy  Paediatric
# S22_TTTGTCATCGAGGTAG-1-reference                        Healthy  Paediatric
# S22_TTTGTCATCTGCTGCT-1-reference                        Healthy  Paediatric
#
#                                                     ... total_counts_ribo
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  ...               NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  ...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  ...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  ...               NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  ...               NaN
# ...                                                 ...               ...
# S22_TTTGTCAGTCGCATCG-1-reference                    ...               NaN
# S22_TTTGTCAGTGTAAGTA-1-reference                    ...               NaN
# S22_TTTGTCATCATGTCCC-1-reference                    ...               NaN
# S22_TTTGTCATCGAGGTAG-1-reference                    ...               NaN
# S22_TTTGTCATCTGCTGCT-1-reference                    ...               NaN
#
#                                                    pct_counts_ribo
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...             NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...             NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...             NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...             NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...             NaN
# ...                                                            ...
# S22_TTTGTCAGTCGCATCG-1-reference                               NaN
# S22_TTTGTCAGTGTAAGTA-1-reference                               NaN
# S22_TTTGTCATCATGTCCC-1-reference                               NaN
# S22_TTTGTCATCGAGGTAG-1-reference                               NaN
# S22_TTTGTCATCTGCTGCT-1-reference                               NaN
#
#                                                    percent_mt2 n_counts
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...         NaN      NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...         NaN      NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...         NaN      NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...         NaN      NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...         NaN      NaN
# ...                                                        ...      ...
# S22_TTTGTCAGTCGCATCG-1-reference                           NaN      NaN
# S22_TTTGTCAGTGTAAGTA-1-reference                           NaN      NaN
# S22_TTTGTCATCATGTCCC-1-reference                           NaN      NaN
# S22_TTTGTCATCGAGGTAG-1-reference                           NaN      NaN
# S22_TTTGTCATCTGCTGCT-1-reference                           NaN      NaN
#
#                                                     percent_chrY XIST-counts
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...           NaN         NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...           NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...           NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...           NaN         NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...           NaN         NaN
# ...                                                          ...         ...
# S22_TTTGTCAGTCGCATCG-1-reference                             NaN         NaN
# S22_TTTGTCAGTGTAAGTA-1-reference                             NaN         NaN
# S22_TTTGTCATCATGTCCC-1-reference                             NaN         NaN
# S22_TTTGTCATCGAGGTAG-1-reference                             NaN         NaN
# S22_TTTGTCATCTGCTGCT-1-reference                             NaN         NaN
#
#                                                    S_score G2M_score
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...     NaN       NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...     NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...     NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...     NaN       NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...     NaN       NaN
# ...                                                    ...       ...
# S22_TTTGTCAGTCGCATCG-1-reference                       NaN       NaN
# S22_TTTGTCAGTGTAAGTA-1-reference                       NaN       NaN
# S22_TTTGTCATCATGTCCC-1-reference                       NaN       NaN
# S22_TTTGTCATCGAGGTAG-1-reference                       NaN       NaN
# S22_TTTGTCATCTGCTGCT-1-reference                       NaN       NaN
#
#                                                    predicted_doublets
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...                NaN  \
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...                NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...                NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...                NaN
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...                NaN
# ...                                                               ...
# S22_TTTGTCAGTCGCATCG-1-reference                                  NaN
# S22_TTTGTCAGTGTAAGTA-1-reference                                  NaN
# S22_TTTGTCATCATGTCCC-1-reference                                  NaN
# S22_TTTGTCATCGAGGTAG-1-reference                                  NaN
# S22_TTTGTCATCTGCTGCT-1-reference                                  NaN
#
#                                                       dataset
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGGCAG...  reference
# CV001_KM10202384-CV001_KM10202394_AAACCTGAGTGTC...  reference
# CV001_KM10202384-CV001_KM10202394_AAACCTGCAGATG...  reference
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTATAG...  reference
# CV001_KM10202384-CV001_KM10202394_AAACCTGGTGTGC...  reference
# ...                                                       ...
# S22_TTTGTCAGTCGCATCG-1-reference                    reference
# S22_TTTGTCAGTGTAAGTA-1-reference                    reference
# S22_TTTGTCATCATGTCCC-1-reference                    reference
# S22_TTTGTCATCGAGGTAG-1-reference                    reference
# S22_TTTGTCATCTGCTGCT-1-reference                    reference
#
# [173684 rows x 43 columns]

# %% [markdown]
# ### HVG selection

# %%
adata_raw = adata_ref.copy()

# %%
# We run highly variable gene selection on the reference data and use these same genes for the query data.

sc.pp.highly_variable_genes(adata_ref, n_top_genes=2000, batch_key="patient_id", subset=True)

adata_query = adata_query[:, adata_ref.var_names].copy()
# Out:
# /Users/mairi.mcclean/mambaforge/envs/label_transfer_scvi/lib/python3.9/site-packages/scipy/sparse/_data.py:133: RuntimeWarning: overflow encountered in expm1
#   result = op(self._deduped_data())
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 3
#       1 # We run highly variable gene selection on the reference data and use these same genes for the query data.
# ----> 3 sc.pp.highly_variable_genes(adata_ref, n_top_genes=2000, batch_key="patient_id", subset=True)
#       5 adata_query = adata_query[:, adata_ref.var_names].copy()
#
# File ~/mambaforge/envs/label_transfer_scvi/lib/python3.9/site-packages/scanpy/preprocessing/_highly_variable_genes.py:465, in highly_variable_genes(adata, layer, n_top_genes, min_disp, max_disp, min_mean, max_mean, span, n_bins, flavor, subset, inplace, batch_key, check_values)
#     461     filt = filter_genes(adata_subset, min_cells=1, inplace=False)[0]
#     463 adata_subset = adata_subset[:, filt]
# --> 465 hvg = _highly_variable_genes_single_batch(
#     466     adata_subset,
#     467     layer=layer,
#     468     min_disp=min_disp,
#     469     max_disp=max_disp,
#     470     min_mean=min_mean,
#     471     max_mean=max_mean,
#     472     n_top_genes=n_top_genes,
#     473     n_bins=n_bins,
#     474     flavor=flavor,
#     475 )
#     477 # Add 0 values for genes that were filtered out
#     478 missing_hvg = pd.DataFrame(
#     479     np.zeros((np.sum(~filt), len(hvg.columns))),
#     480     columns=hvg.columns,
#     481 )
#
# File ~/mambaforge/envs/label_transfer_scvi/lib/python3.9/site-packages/scanpy/preprocessing/_highly_variable_genes.py:215, in _highly_variable_genes_single_batch(adata, layer, min_disp, max_disp, min_mean, max_mean, n_top_genes, n_bins, flavor)
#     213 df['dispersions'] = dispersion
#     214 if flavor == 'seurat':
# --> 215     df['mean_bin'] = pd.cut(df['means'], bins=n_bins)
#     216     disp_grouped = df.groupby('mean_bin')['dispersions']
#     217     disp_mean_bin = disp_grouped.mean()
#
# File ~/mambaforge/envs/label_transfer_scvi/lib/python3.9/site-packages/pandas/core/reshape/tile.py:263, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     259 mn, mx = (mi + 0.0 for mi in rng)
#     261 if np.isinf(mn) or np.isinf(mx):
#     262     # GH 24314
# --> 263     raise ValueError(
#     264         "cannot specify integer `bins` when input data contains infinity"
#     265     )
#     266 if mn == mx:  # adjust end points before binning
#     267     mn -= 0.001 * abs(mn) if mn != 0 else 0.001
#
# ValueError: cannot specify integer `bins` when input data contains infinity

# %% [markdown]
# ### Train reference
#
# > From tutorial: SCANVI tends to perform better in situations where it has been initialized using a pre-trained SCVI model.

# %% [markdown]
# - scVI model

# %%
scvi.model.SCVI.setup_anndata(adata_ref, batch_key="dataset")

# %%
# Added for sarches params following tutorial; check if we require it?
arches_params = dict(
    use_layer_norm="both",
    use_batch_norm="none",
    encode_covariates=True,
    dropout_rate=0.2,
    n_layers=2,
)

vae_ref = scvi.model.SCVI(adata_ref, **arches_params)
vae_ref.train()

# %%
adata_ref.obsm["X_scVI"] = vae_ref.get_latent_representation()
sc.pp.neighbors(adata_ref, use_rep="X_scVI")
sc.tl.leiden(adata_ref)
sc.tl.umap(adata_ref)

# %%
sc.pl.umap(
    adata_ref,
    color=["dataset", "annotation_broad"],
    frameon=False,
    ncols=1,
)

# %% [markdown]
# ### Update with query

# %% [markdown]
# - scANVI model

# %%
adata_ref.obs["labels_scanvi"] = adata_ref.obs["annotation_broad"].values

# %%
# unlabeled category does not exist in adata.obs[labels_key]
# so all cells are treated as labeled
vae_ref_scanvi = scvi.model.SCANVI.from_scvi_model(
    vae_ref,
    unlabeled_category="unknown",
    labels_key="labels_scanvi",
)

# %%
vae_ref_scanvi.train(max_epochs=20, n_samples_per_label=100)

# %%
adata_ref.obsm["X_scANVI"] = vae_ref_scanvi.get_latent_representation()
sc.pp.neighbors(adata_ref, use_rep="X_scANVI")
sc.tl.leiden(adata_ref)
sc.tl.umap(adata_ref)

# %%
sc.pl.umap(
    adata_ref,
    color=["leiden", "annotation_broad"],
    frameon=False,
    ncols=1,
)

# %% [markdown]
# ### Update with query

# %%
dir_path_scan = "/Volumes/LaCie/data_lake/Mairi_example/processed_files/scanvi/models/"
vae_ref_scanvi.save(dir_path_scan, overwrite=True)

# %%
# again a no-op in this tutorial, but good practice to use
scvi.model.SCANVI.prepare_query_anndata(adata_query, dir_path_scan)

# %%
vae_ref_scanvi.registry_

# %%
vae_query = scvi.model.SCANVI.load_query_data(
    adata_query,
    dir_path_scan,
)

# %%
vae_query.train(
    max_epochs=100,
    plan_kwargs=dict(weight_decay=0.0),
    check_val_every_n_epoch=10,
)

# %%
adata_query.obsm["X_scANVI"] = vae_query.get_latent_representation()
adata_query.obs["predictions"] = vae_query.predict()

# %%
df = adata_query.obs.groupby(["annotation_broad", "predictions"]).size().unstack(fill_value=0)
norm_df = df / df.sum(axis=0)

plt.figure(figsize=(8, 8))
_ = plt.pcolor(norm_df)
_ = plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns, rotation=90)
_ = plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xlabel("Predicted")
plt.ylabel("Observed")

# %% [markdown]
# ### Analyze reference and query

# %%
adata_full = adata_query.concatenate(adata_ref)

# %%
adata_full.obs.batch.cat.rename_categories(["Query", "Reference"])

# %%
full_predictions = vae_query.predict(adata_full)
print(f"Acc: {np.mean(full_predictions == adata_full.obs.annotation_broad)}")

adata_full.obs["predictions"] = full_predictions

# %%
sc.pp.neighbors(adata_full, use_rep="X_scANVI")
sc.tl.leiden(adata_full)
sc.tl.umap(adata_full)

# %%
sc.pl.umap(
    adata_full,
    color=["dataset", "annotation_broad"],
    frameon=False,
    ncols=1,
)

# %%
ax = sc.pl.umap(
    adata_full,
    frameon=False,
    show=False,
)
sc.pl.umap(
    adata_full[: adata_query.n_obs],
    color=["predictions"],
    frameon=False,
    title="Query predictions",
    ax=ax,
    alpha=0.7,
)

ax = sc.pl.umap(
    adata_full,
    frameon=False,
    show=False,
)
sc.pl.umap(
    adata_full[: adata_query.n_obs],
    color=["annotation_broad"],
    frameon=False,
    title="Query observed cell types",
    ax=ax,
    alpha=0.7,
)
